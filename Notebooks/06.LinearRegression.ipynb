# %%
"""import modules"""
import torch
import torch.nn as nn
import numpy as np
from sklearn import datasets
import matplotlib.pyplot as plt

# %% [markdown]
# ## Train Pipeline
#
# 01. Design model (input, output, forward pass)
# 02. Construct loss and optimizer
# 03. Training loop
#     - Forward Pass = compute prediction and loss
#     - Backward = compute gradients
#     - Update weights

# %%
# 0) Prepare data
X_numpy, y_numpy = datasets.make_regression(n_samples=100, n_features=1, noise=20, random_state=4)

# cast to float Tensor
X = torch.from_numpy(X_numpy.astype(np.float32))
y = torch.from_numpy(y_numpy.astype(np.float32))
y = y.view(y.shape[0], 1) #reshaping the tensor

n_samples, n_features = X.shape

# 1) Model
# Linear model f = wx + b
input_size = n_features
output_size = 1
model = nn.Linear(input_size, output_size)

# 2) Loss and optimizer
learning_rate = 0.01

criterion = nn.MSELoss()
optimizer = torch.optim.SGD(model.parameters(), lr=learning_rate)  

# 3) Training loop
num_epochs = 100
for epoch in range(num_epochs):
    # Forward pass and loss
    y_predicted = model(X)
    loss = criterion(y_predicted, y)
    
    # Backward pass and update
    loss.backward() #calculate the gradient
    optimizer.step() #update the weight

    # zero grad before new step
    optimizer.zero_grad()

    if (epoch+1) % 10 == 0:
        print(f'epoch: {epoch+1}, loss = {loss.item():.4f}')

# Plot
predicted = model(X).detach().numpy() # .detach: gradient calculation will be set to False

plt.plot(X_numpy, y_numpy, 'ro')
plt.plot(X_numpy, predicted, 'b')
plt.show()
# Out:
# epoch: 10, loss = 4028.3188
# epoch: 20, loss = 2839.7854
# epoch: 30, loss = 2029.4938
# epoch: 40, loss = 1476.9537
# epoch: 50, loss = 1100.0980
# epoch: 60, loss = 843.0140
# epoch: 70, loss = 667.6013
# epoch: 80, loss = 547.8909
# epoch: 90, loss = 466.1792
# epoch: 100, loss = 410.3944
